# %% [markdown]
# # Inaugural Project

# %% [markdown]
# Imports and set magics:

# %%
import numpy as np

# %load_ext autoreload
# %autoreload 2

# import your own code
from HouseholdSpecializationModel import HouseholdSpecializationModelClass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Question 1

# %%
model = HouseholdSpecializationModelClass()

# %%
opt = model.solve_discrete(do_print=True)
# Out:
# LM = 4.5000
# HM = 4.5000
# LF = 4.5000
# HF = 4.5000

# %%
model.par.sigma = 1.1
model.solve_discrete(do_print=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15768\2743383417.py in <cell line: 2>()
#       1 model.par.sigma = 1.1
# ----> 2 model.solve_discrete(do_print=True)
#
# c:\Users\gmf123\Dropbox\Repositories\course\projects-2023-test\inauguralproject\HouseholdSpecializationModel.py in solve_discrete(self, do_print)
#      88
#      89         # b. calculate utility
# ---> 90         u = self.calc_utility(LM,HM,LF,HF)
#      91
#      92         # c. set to minus infinity if constraint is broken
#
# c:\Users\gmf123\Dropbox\Repositories\course\projects-2023-test\inauguralproject\HouseholdSpecializationModel.py in calc_utility(self, LM, HM, LF, HF)
#      55
#      56         # b. home production
# ---> 57         assert np.isclose(par.sigma,1.0)
#      58         H = HM**(1-par.alpha)*HF**par.alpha
#      59
#
# AssertionError:
